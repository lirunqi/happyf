# %%
import pandas as pd
import json

# %%
f = open('r.json',encoding='utf-8')

# %%
js_dt = json.load(f)
pd.json_normalize(js_dt)
# Out:
#                                                   al  \
# 0  [{'c': 1, 'l': [[{'t': 1678646790, 'p': 8, 'h'...
#
#                                                   el  \
# 0  [{'c': 1001, 'l': [[{'t': 1678646643, 'w': 0, ...
#
#                                                   ol  \
# 0  [{'c': 1, 'l': [[{'t': 1678646762, 'p': 26, 'o...
#
#                                                  col     m.id        m.mt  \
# 0  [{'c': 1001, 'l': [[{'t': 1678647334, 'p': 34,...  1868860  1678640400
#
#    m.st.id m.st.cn m.st.tr m.st.en m.sc.ht m.sc.ft
# 0        6       完       完      FT  [1, 3]  [3, 4]

# %%
pd.json_normalize(js_dt,['al','l'],[['al','c']])
# Out:
#                                                    0  \
# 0  {'t': 1678646790, 'p': 8, 'h': 2.17, 'a': 1.6,...
# 1  {'t': 1678647417, 'p': 1, 'h': 1.09, 'a': 6, '...
# 2  {'t': 1678647533, 'p': 1, 'h': 0, 'a': 0, 'rt'...
# 3  {'t': 1678643562, 'p': 1, 'h': 1.66, 'a': 2.29...
# 4  {'t': 1678647413, 'p': -1, 'h': 0, 'a': 0, 'rt...
# 5  {'t': 1678646648, 'p': 2, 'h': 0, 'a': 0, 'rt'...
#
#                                                    1  \
# 0  {'t': 1678646748, 'p': 8, 'h': 2.15, 'a': 1.62...
# 1  {'t': 1678647325, 'p': 1, 'h': 1.1, 'a': 5.76,...
# 2  {'t': 1678647472, 'p': 1, 'h': 1.02, 'a': 8.69...
# 3                                               None
# 4  {'t': 1678647325, 'p': -1, 'h': 6.55, 'a': 1.0...
# 5  {'t': 1678646495, 'p': 2, 'h': 1.21, 'a': 4.12...
#
#                                                    2  \
# 0  {'t': 1678646589, 'p': 8, 'h': 2.09, 'a': 1.68...
# 1  {'t': 1678647295, 'p': 1, 'h': 1.12, 'a': 5.34...
# ...
